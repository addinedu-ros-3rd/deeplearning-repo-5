# %%
# !pwd
# Out:
# /content

# %%
# !mkdir ./dataset
# !ls
# Out:
# mkdir: cannot create directory ‘./dataset’: File exists
# dataset  drive	sample_data

# %%
# %cd dataset
# Out:
# /content/dataset

# %%
# !pwd
# Out:
# /content/dataset

# %%
# !unzip -qq "/content/drive/MyDrive/wildlife_model/dataset.zip"

# %%
# source directory : /content/dataset
# target directory : /content/drive/MyDrive/wildlife_model/dataset

# !cp -ar /content/dataset/* /content/drive/MyDrive/wildlife_model/dataset/
# Out:
# ^C
