# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# !mkdir ./dataset
# %cd dataset
# Out:
# /content/dataset

# %%
# /content/drive/MyDrive/wildlife_model/dataset.zip
# !unzip -qq "/content/drive/MyDrive/wildlife_model/dataset.zip"

# %%
# %cd /content/drive/MyDrive/wildlife_model/yolov8
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1zkVa-b03spCRpJ6ZZO5M9ICQz8vvSVQC/wildlife_model/yolov8
# /content/drive/.shortcut-targets-by-id/1zkVa-b03spCRpJ6ZZO5M9ICQz8vvSVQC/wildlife_model/yolov8

# %%
# %pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.4/660.4 kB 7.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 45.3/78.2 GB disk)

# %%
from ultralytics import settings

# Update a setting
settings.update({'datasets_dir': '/content/dataset'})

# View all settings
print(settings)
# Out:
# {'settings_version': '0.0.4', 'datasets_dir': '/content/dataset', 'weights_dir': 'weights', 'runs_dir': 'runs', 'uuid': '569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb', 'sync': True, 'api_key': '', 'clearml': True, 'comet': True, 'dvc': True, 'hub': True, 'mlflow': True, 'neptune': True, 'raytune': True, 'tensorboard': True, 'wandb': True}

# %%
# !ls
# Out:
# data_process.ipynb  runs  train_log.txt  train_yolov8.ipynb  yolov8n.pt

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('./runs/detect/train9/weights/last.pt')  # load a pretrained model (recommended for training)
#model = YOLO('yolov8n.yaml').load('last.pt')  # build from YAML and transfer weights

# View all settings
print(settings)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1zkVa-b03spCRpJ6ZZO5M9ICQz8vvSVQC/wildlife_model/yolov8

# %%
# Train the model
results = model.train(data='/content/dataset/data_eng.yaml', batch=64, epochs=3, imgsz=416)

# Resume training
#results = model.train(resume=True)
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
